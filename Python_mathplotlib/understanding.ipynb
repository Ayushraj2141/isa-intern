# %%
## importing
import matplotlib.pyplot as plt

# %% [markdown]
# ### Straight Line Plot

# %%
# simple curve
# x = [1,2,3,4,5,6,7,8,9] # taking the values 
# y = [1,4,9,16,25,36,49,64,81] -- for parabolaa

# plot of straight line

x = [1,2,3]
y = [2,4,6]

plt.plot(x,y) # plotting it  -- agar isi ka bar bnaana hai toh
# bahut plain plain sa lgg rhaa haii??-- isme color daalna hai?
c=['r','g','b']


plt.show() # showing the plot to the user

# %% [markdown]
# ### Scatter Plot

# %%
import matplotlib.pyplot as plt

day = [1,2,3,4,5,6,7]
no = [2,3,1,4,5,3,6]
no2 = [4,6,8,11,4,2,9]

# colors =["r","y","g","b","r","g","r"] # for color -- konse colors available hai for changing ye bhi dekhnaa -- colors could also be changed as 
# a range of colors using cmap parameter -- colormap -- kaafi trh k hote hai with the flow chal jayegaa pataa
colors =[35,89,67,10,88,78,90]

# colorbar taaki pata chlee konsaa color use huaa haii

# want to change the sizes also ??
'''
Want to change to change the sizes too? -- do it using size parameter 
'''

# Want to change transperancy alsoo? isee alphaa parameter
# a = [0.1,0.2,0.40,0.50,0.20,1,0.70] -- Aise alag alag individually bhi change krr sktee haiii -- range from 0 to 1 only 
sizes = [1000,200,400,500,200,800,700]

'''
do not liked the plane circles? -- can change it using the marker syntax
aisaa nhi haii kuch bhi daal sktee hai ye dekhnaa pdegaa kya allowed hai and kya nhi 
jaise star allowed tha jab dekhaa but baaki kuch allowed nhi tha jaise @ , # ya a,b,c,d wgera wgeraa
edge color bhi change kr sktee haii using edgecolor ="color " -- thickness could also be change using linewidth = int
'''
plt.scatter(day,no, c=colors, s = sizes , alpha = 1 , marker = "*",edgecolors="r",linewidths=0.5,cmap="BrBG")
# Agar zyadaaa scatter functions usee krengee toh ekk hii plot k under bht saare points plot ho jayengee -- kaisee??
# plt.scatter(day,no2, c=colors, s = sizes , alpha = 0.8 ) -- could see by uncommenting this part 


# syntax with use of color or only c could also be used
# size nhi s use krnaa hai for sizes -- Also check ki ye size ki units kya haii?
# want to give title ?

t = plt.colorbar() # achaaa isme direct plt.colorbar.set_label krnee se nhi huaa kyunki woh uske properties mai nhi thaa shydd isse checkk krnaa ek baari
t.set_label("Color-Bar")
plt.title("Scatter plot",fontsize = 15)
plt.xlabel("Day",fontsize = 15)
plt.ylabel("Number",fontsize = 15)

plt.show()

# %% [markdown]
# ### Bar Graph Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x = ["Python","C++","Java"]
y = [90,60,70] # Popularity of these languages
z = [10,20,30] 
t = np.arange(len(x)) # iska use check krnaa
width = 0.8
p1 = [j + width for j in t]
# c = ["r","g","b"] # yaha pr c nhi color hi likhnaa pdegaa 
# align = senter / edge -- isse kahaa pr align krnaa hai 
plt.xlabel("Languages",fontsize = 20)
plt.ylabel("Popularity",fontsize = 20)
plt.title("Bar_graph-Plot")

# plt.bar(x,y,label = "plot" )#iske liye legend chahiyee  -- issee overwrite hogyaa ye nhi krnaa
plt.barh(p1,y,width, color = "r" , align = "center"  , alpha = 0.8) # for horizontal bargraph easyy just use -barh that's it 
plt.bar(p1,z,width, color = "y" , align = "center"  , alpha = 0.8 ) # but this will just overlap not distinguish 
#p1 ka use krkee side mai aajana chahiye thaa woh nhi aaya isse bhi ek baar check krnaa hai 

# plt.legend() -- iska usee krtee hai label lganne k liyee likhtee hai na graph mai 1 unit in x is equal to aise aisee 

plt.xticks(t+width,x,rotation = 10) # iske baare mai ek baar documentation mai pdhnaa 
plt.show()

# %% [markdown]
# ### Histogram Plots

# %%
import matplotlib.pyplot as plt
import numpy as np 
import random

# x = np.random.randint(10,60,(50)) # pprint 50 random integer numbers between 10 and 60 -- hrr baar use krne pr change hogaa -- sirf ek baar use
# print(x)

# ab kyunki data bht faila huaa haii ek bins parameter hota hai jisse ek trh k data ko club krr sktee haii

l = [10,20,30,40,50,60] 

x= [41, 45 ,14 ,47, 41, 36, 29, 40, 36, 49, 24, 26, 15, 24, 34, 52, 50, 20, 20, 18 ,51, 13, 16, 53,10, 23, 44, 11, 39, 57, 33, 25, 52, 28, 53, 38 ,34, 18, 37, 20 ,48 ,18 ,54 ,28, 14 ,53 ,36, 56,
49, 27] 
# plt.hist(x , "auto" , (0,200) , edgecolor = "r") -- ye pata nhii shayad positional dependent hai koi aur position pr yee kaam nhi kiyaa idk why

# plt.hist(x , edgecolor = "r", cumulative = -1) # cumulative se reverse order mai 
# plt.hist(x , edgecolor = "r", bottom = 20) # bottom kaha se start hogaa -- baaki part kat jayegaa
# plt.hist(x , edgecolor = "r", histtype="step") # kis trh ka type hai histogram kaa
# plt.hist(x , edgecolor = "r", orientation="horizontal") #change of orientation
# rwidth = int to change the width 
# plt.hist(x , edgecolor = "r", log=True) # log mai values lenaa

plt.hist(x , edgecolor = "r" ) # log mai values lenaa

plt.axvline(45) # graph ko divide krnaa 
# use range paramter for better understanding
'''
label , colors , widths ,align , label--plt.legend() -- ek se zyada label jitne dengee utnee aajayengee, boundaries , liner width wgera wgeraa araam se change kiya jaa sktaa hai baar baar isse pdhne ki zroorat nhii '''
# Out:
# '\nlabel , colors , widths ,align , label--plt.legend() -- ek se zyada label jitne dengee utnee aajayengee, boundaries , liner width wgera wgeraa araam se change kiya jaa sktaa hai baar baar isse pdhne ki zroorat nhii '

# %% [markdown]
# ### Stem Plot -- in signals and systems mainly

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,3,5,6,7]

plt.stem(x,y,linefmt=":",markerfmt="ro") # To change the shape of the line
# Bottom = int use krkee bottom line mai changes kr sktee hai , basefmt ="" to change base line , label to label also use plt.legend() further
# use_line_collection = False to change the base line -- these dotted lines 
# orientation for change the orientation

plt.show()

# %% [markdown]
# ### Step Plot -- signals in communication

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [2,4,6,8]

plt.step(x,y,marker = "o" , ms = 10 , mfc = "r" , label = "Python") # ms -- marker size and mfc -- marker face color
plt.grid()
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.legend(loc=4) # To change the location of the label mentioned in step
plt.show()

# %% [markdown]
# ### Axis chanegs

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[2,3,2,6,4]

plt.plot(x,y)
plt.title("Understanding the Axes")
plt.xlabel("X-axis" , fontsize = 20)
plt.ylabel("Y-axis" , fontsize = 20)

plt.xticks(x) # ek baar check krnaa but shyd iskaa ye mtlb haii kii aur achee se axes ko dikhaana 
plt.yticks(y)
plt.grid()

# change krnaa  limits koo

# plt.xlim(0,10)
# plt.ylim(0,10) -- limits ko changee krnaa

plt.axis([0,10,0,7])


plt.show()

# %% [markdown]
# ### Making a subplot

# %%
import matplotlib.pyplot as plt
x =[1,2,3,4,5]
y =[2,4,6,8,10]
plt.subplot(2,2,1)
plt.plot(x,y,color="r")

plt.subplot(2,2,2)
plt.pie([1],colors="g") # Bhai ye kyaa baat huaa khi sirf c khii colors aur khi color ye kya badtameezi hai ye dekhnaa pdegaa ek baari

x1=[10,20,30,40]

plt.subplot(2,2,3)
plt.pie(x1) # overwrite hogyaa basically bss

x2=["a","b","c","d","e"]
y2=[1,2,3,4,5]

# i want ki saare plot alg alg hoo -- subplot
plt.subplot(2,2,4)
plt.bar(x2,y2) # isse bhasad mach gyii thorii sii bht zyadaa mismatch saa hogyaa haii 

plt.show()

# %% [markdown]
# ### Fill between plot

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [2,4,6,8,10]


plt.fill_between(x=[1,3],y1=2,y2=9,alpha = 0.8 , color = "r") # Yaha positional arguments dene pdengee 
# plt.fill_between(x=[1,3],y1=2,y2=9,alpha = 0.8 , color = "r") # agar positions nhi denee toh where & ka bhi usee krr sktee hai but 
# number letaa hai naaki list so numpy ko import krke list ko change krnaa pdegaa   

plt.title("Fill Shape")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.plot(x,y)
plt.show()

# %% [markdown]
# #### How to write text in between graphs

# %%
import matplotlib.pyplot as plt
x = [1,2,5,2,3]
y = [2,4,6,7,9]

plt.text(2,7,"Python", rotation = 15,style = "oblique" , bbox={"facecolor" : "red" },alpha = 0.6)
# Ye dekhnaa ki jo box ka size hai usse kaise change kiyaa jaa sktaa hai
 # isme dekhnaa ki us point k about ye ghum bhi sktaa haii kya -- haan ghum sktaa hai
# Positional arguments x and y mai dena pdegaa like humme exactly konsee coordinates mai woh point chahiyee
'''
color,style-kuch trh kai hai woh dekhnaa pdegaa , size wgeraa change kiyaa jaa sktaa haii 
'''
plt.plot(x,y)

'''
Agar kuch arrow wgera show krnaa hai kuch specifically dikhana haii toh usse annotate k help se kiyaa jaa sktaa haii
'''

#label direct legend mai bhi kr sktee haii
plt.legend(["Helloo"] ,loc= 4) ## -- facecolor , edgecolor and framealpha jaisi cheeze bhi usee krrkee bdde araam se in cheezo ko tackle kiyaa jaa sktaa haii
# shadow = True 
plt.annotate("This yes this",xy=(2,4),xytext=(3,3),arrowprops=dict(facecolor="green ",shrink = 75))

plt.show()

# %% [markdown]
# ### Area vs Stack Plot

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
area = [1,3,7,4]
# For multiple areas to be plotted
area1 = [3,5,3,8]
area2 = [1,7,9,4]

l = ["area","area1","area2"]

plt.stackplot(x,area,area1,area1,labels = l) # Apne aap hi alag alag color mai plotting hogyii -- yahaa pr labels aayegaa label nhii

plt.legend()
plt.show()
